# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import sys
from datetime import datetime
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error,r2_score
import pyarrow
import fastparquet

# %%
# read data from csv
path = 'C:/Users/parni/Downloads/'
df_training = pd.read_parquet(path+'train_nontemporal_regression.parquet.gz')
df_test = pd.read_parquet(path+'test_nontemporal_regression.parquet.gz')
#df_training.head()
# Out:
#                                         powiat_voivod  cloud_cover  \
# DATE
# 2017-01-01  powiat aleksandrowski, kujawsko-pomorskie     4.746750
# 2017-01-01              powiat augustowski, podlaskie     8.000000
# 2017-01-01               powiat bełchatowski, łódzkie     5.923833
# 2017-01-01           powiat biała podlaska, lubelskie     6.000000
# 2017-01-01                powiat białystok, podlaskie     8.000000
#
#             wind_speed  humidity  precipitation  snow_depth  temperature  \
# DATE
# 2017-01-01         0.0      88.4            1.0         0.0          1.8
# 2017-01-01        50.0      95.0            9.0         0.0          0.4
# 2017-01-01         0.0      80.0            0.0         5.0          0.0
# 2017-01-01         0.0      78.0            0.0         0.0          0.9
# 2017-01-01         0.0      89.0            0.0         0.0          0.4
#
#                     voivodship  animal stock - total  \
# DATE
# 2017-01-01  kujawsko-pomorskie             44.997895
# 2017-01-01           podlaskie             47.547318
# 2017-01-01             łódzkie             43.636364
# 2017-01-01           lubelskie             21.265306
# 2017-01-01           podlaskie             47.549020
#
#             area by land - utilised agricultural area  ...  \
# DATE                                                   ...
# 2017-01-01                                   1.718015  ...
# 2017-01-01                                   4.963793  ...
# 2017-01-01                                   3.809493  ...
# 2017-01-01                                   0.138255  ...
# 2017-01-01                                   0.305201  ...
#
#             crop production - permanent meadows, area in ha, total  \
# DATE
# 2017-01-01                                           4.884211
# 2017-01-01                                          16.300784
# 2017-01-01                                           7.991736
# 2017-01-01                                           8.612245
# 2017-01-01                                          16.303922
#
#             crop production - permanent pastures, area in ha, total  \
# DATE
# 2017-01-01                                           0.854737
# 2017-01-01                                           2.241712
# 2017-01-01                                           0.686983
# 2017-01-01                                           0.551020
# 2017-01-01                                           2.245098
#
#              CAQI_idx  isUrban  season    holiday_name  is_school_holiday  \
# DATE
# 2017-01-01  24.968064        0  Winter  New Year's Day                0.0
# 2017-01-01  61.553125        0  Winter  New Year's Day                0.0
# 2017-01-01  11.000000        0  Winter  New Year's Day                0.0
# 2017-01-01  71.000000        1  Winter  New Year's Day                0.0
# 2017-01-01  49.878097        1  Winter  New Year's Day                0.0
#
#             is_lockdown  is_have_coalplant  is_weekend
# DATE
# 2017-01-01          0.0                0.0           1
# 2017-01-01          0.0                0.0           1
# 2017-01-01          0.0                1.0           1
# 2017-01-01          0.0                0.0           1
# 2017-01-01          0.0                0.0           1
#
# [5 rows x 123 columns]

# %%
# Drop Powiat and Voivodo columns from whole data
df_training=df_training.drop(columns=['powiat_voivod', 'voivodship'])
df_test=df_test.drop(columns=['powiat_voivod', 'voivodship'])

# %%
X_train = df_training.drop(columns=['CAQI_idx'])  #independent columns
y_train = df_training['CAQI_idx'].values    #target column
X_test = df_test.drop(columns=['CAQI_idx'])  #independent columns
y_test = df_test['CAQI_idx'].values    #target column

# %%
#Define variables for One Hot Encoding
categorical_ix = X_train.select_dtypes(include=['object', 'bool']).columns

# %%
#Define variables for Scaling
numerical_ix = X_train.select_dtypes(include=['int64', 'float64']).columns

# %%
# Data preparation for the columns
t = [('cat',OneHotEncoder(handle_unknown='ignore'),categorical_ix),('num',StandardScaler(),numerical_ix)]
col_transform = ColumnTransformer(transformers=t)

# %%
# Transform Categorical and Numerical columns in Train Data using defined Column Transformer
X_train_new = col_transform.fit_transform(X_train)

# %%
# define the RF model
model = RandomForestRegressor(n_estimators = 100, max_depth=3, min_samples_split=3, n_jobs=-1, random_state=0)

# %%
# Cross validate model on Train data
cv = RepeatedKFold(n_splits=10, n_repeats=1, random_state=0)
cvs = cross_val_score(model, X_train_new, y_train, scoring='neg_root_mean_squared_error', cv=cv)

print("All cross val scores:", cvs) 
print("Mean of all scores: ", cvs.mean())

model.fit(X_train_new, y_train)
# Out:
# All cross val scores: [-14.24310117 -14.32957994 -14.35673585 -14.32947908 -14.38418935
#  -14.26603412 -14.38975639 -14.35414927 -14.30805926 -14.3896626 ]
# Mean of all scores:  -14.335074701869917
# RandomForestRegressor(max_depth=3, min_samples_split=3, n_jobs=-1,
#                       random_state=0)

# %%
# Transform columns in Test Data and apply model to predict target
X_test_new = col_transform.transform(X_test)
yhat = model.predict(X_test_new)

# evaluate predictions on Test
mse = mean_squared_error(y_test, yhat, squared=False)
print(mse)
#print(r2_score(y_test, yhat))

# apply model to predict training data target values
yhat_train=model.predict(X_train_new).reshape(-1,1)
yhat_train=yhat_train.ravel()

# evaluate predictions on Train
mse = mean_squared_error(y_train, yhat_train, squared=False)
print(mse)
#print(r2_score(y_train, yhat_train))
# Out:
# 12.390379909765263
# 0.08238713713632007
# 14.328028446453162
# 0.2503707794950579

# %%
# Calculate the root mean square error (RMSE) for test and training data
N = len(y_test)
rmse_test = np.sqrt(np.sum((np.array(y_test).flatten() - np.array(yhat).flatten())**2)/N)
print("RMSE TEST: ", rmse_test)     

N = len(y_train)
rmse_train = np.sqrt(np.sum((np.array(y_train).flatten() - np.array(yhat_train).flatten())**2)/N)
print("RMSE train: ", rmse_train)
# Out:
# RMSE TEST:  12.390379909765263
# RMSE train:  14.328028446453162

# %%
feat_scores = model.feature_importances_

#Creating a dataframe for feature importance
feature_imp_df = \
pd.DataFrame({
    'features' :col_transform.get_feature_names_out(),
    'importance' : np.round(feat_scores, 3)
}).set_index('features').sort_values('importance')

# %%
f_plot = feature_imp_df.plot(kind='barh', edgecolor='k', figsize=(6, 60))

f_plot.bar_label(ax.containers[0], fontsize = 13, padding = 5);
f_plot.legend().remove()
f_plot.set_title("Feature Importance");
